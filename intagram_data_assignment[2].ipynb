# %%
import pandas as pd

# %%
data=pd.read_csv('instagram_global_top_1000.csv')
data
# Out:
#     Country  Rank        Account                           Title  \
# 0       All     1      cristiano               Cristiano Ronaldo
# 1       All     2    kyliejenner                         Kylie 🤍
# 2       All     3       leomessi                       Leo Messi
# 3       All     4  kendalljenner                         Kendall
# 4       All     5    selenagomez                    Selena Gomez
# ..      ...   ...            ...                             ...
# 995     All   996  senoritasaeva                      Dina Saeva
# 996     All   997    manuelneuer                    Manuel Neuer
# 997     All   998      sahilkhan  India’s Youth & Fitness IC⭕️N®
# 998     All   999    mohanshakti                    Shakti Mohan
# 999     All  1000       eduincaz                       Eduin Caz
#
#                                          Link  \
# 0        https://www.instagram.com/cristiano/
# 1      https://www.instagram.com/kyliejenner/
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               1000 non-null   object
#  1   Rank                  1000 non-null   int64
#  2   Account               1000 non-null   object
#  3   Title                 983 non-null    object
#  4   Link                  1000 non-null   object
#  5   Category              909 non-null    object
#  6   Followers             1000 non-null   float64
#  7   Audience Country      993 non-null    object
#  8   Authentic engagement  1000 non-null   float64
#  9   Engagement avg        1000 non-null   float64
#  10  Scraped               1000 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 86.1+ KB

# %%
a=data.head(20)
a
# Out:
#    Country  Rank                     Account                Title  \
# 0      All     1                   cristiano    Cristiano Ronaldo
# 1      All     2                 kyliejenner              Kylie 🤍
# 2      All     3                    leomessi            Leo Messi
# 3      All     4               kendalljenner              Kendall
# 4      All     5                 selenagomez         Selena Gomez
# 5      All     6                     zendaya              Zendaya
# 6      All     7               kimkardashian  Kim Kardashian West
# 7      All     8                     beyonce             Beyoncé
# 8      All     9                arianagrande        Ariana Grande
# 9      All    10                billieeilish        BILLIE EILISH
# 10     All    11                    neymarjr                NJ 🇧🇷
# 11     All    12                lalalalisa_m                 LISA
# 12     All    13              jennierubyjane                    J
# ...

# %% [markdown]
# # 2a.How many influencers in the top 20 are into sports?

# %%
#The number of influencers in the top 20 that are into Sports
b=a[(a['Category']=='Sports with a ball')]
b
# Out:
#    Country  Rank      Account              Title  \
# 0      All     1    cristiano  Cristiano Ronaldo
# 10     All    11     neymarjr              NJ 🇧🇷
# 14     All    15  virat.kohli        Virat Kohli
#
#                                       Link            Category    Followers  \
# 0     https://www.instagram.com/cristiano/  Sports with a ball  400100000.0
# 10     https://www.instagram.com/neymarjr/  Sports with a ball  169800000.0
# 14  https://www.instagram.com/virat.kohli/  Sports with a ball  182600000.0
#
#    Audience Country  Authentic engagement  Engagement avg  \
# 0             India             7800000.0       9500000.0
# 10           Brazil             2800000.0       4000000.0
# 14            India             2100000.0       2400000.0
#
#                        Scraped
# 0   2022-02-07 16:50:24.798803
# 10  2022-02-07 16:50:24.798803
# 14  2022-02-07 16:50:24.798803

# %% [markdown]
# # 2b.How many musicians were in the top 100, which countries were their audience from and how many followers did they have?

# %%
c=data.head(100)
pd.set_option('display.max_rows',100)
c
# Out:
#    Country  Rank                     Account                        Title  \
# 0      All     1                   cristiano            Cristiano Ronaldo
# 1      All     2                 kyliejenner                      Kylie 🤍
# 2      All     3                    leomessi                    Leo Messi
# 3      All     4               kendalljenner                      Kendall
# 4      All     5                 selenagomez                 Selena Gomez
# 5      All     6                     zendaya                      Zendaya
# 6      All     7               kimkardashian          Kim Kardashian West
# 7      All     8                     beyonce                     Beyoncé
# 8      All     9                arianagrande                Ariana Grande
# 9      All    10                billieeilish                BILLIE EILISH
# 10     All    11                    neymarjr                        NJ 🇧🇷
# 11     All    12                lalalalisa_m                         LISA
# ...

# %%
d=c[['Category','Followers','Audience Country']]
d
# Out:
#                                              Category    Followers  \
# 0                                  Sports with a ball  400100000.0
# 1                             Fashion|Modeling|Beauty  308800000.0
# 2                           Sports with a ball|Family  306300000.0
# 3                                    Modeling|Fashion  217800000.0
# 4                                     Music|Lifestyle  295800000.0
# 5                     Cinema|Actors/actresses|Fashion  127800000.0
# 6                                      Fashion|Beauty  284900000.0
# 7                                       Music|Fashion  237200000.0
# 8                                               Music  294100000.0
# 9                                               Music  100000000.0
# 10                                 Sports with a ball  169800000.0
# 11                                              Music   73100000.0
# 12                                              Music   62300000.0
# ...

# %%
#The number of musicians in the top 100 the country of their audience and the followers
m=d[(d['Category']=='Music')]
m
# Out:
#    Category    Followers Audience Country
# 8     Music  294100000.0    United States
# 9     Music  100000000.0    United States
# 11    Music   73100000.0        Indonesia
# 12    Music   62300000.0        Indonesia
# 19    Music  219800000.0            India
# 21    Music   55100000.0        Indonesia
# 23    Music  174000000.0    United States
# 29    Music   44500000.0            India
# 30    Music  102600000.0    United States
# 34    Music   37800000.0    United States
# 36    Music   49100000.0    United States
# 41    Music   47300000.0           Mexico
# 46    Music   78700000.0           Mexico
# 49    Music  160200000.0    United States
# 55    Music   66500000.0           Brazil
# 62    Music   47300000.0           Mexico
# 67    Music  125800000.0    United States
# 68    Music   45200000.0        Indonesia
# 75    Music   23600000.0        Indonesia
# 76    Music  151900000.0           Brazil
# 78    Music   60000000.0           Brazil
# ...

# %%
m.shape
# Out:
# (24, 3)

# %%
data.info()

# %%
df=data[['Audience Country','Followers','Engagement avg','Title']]
df
# Out:
#     Audience Country    Followers  Engagement avg  \
# 0              India  400100000.0       9500000.0
# 1      United States  308800000.0      10100000.0
# 2          Argentina  306300000.0       6500000.0
# 3      United States  217800000.0       5400000.0
# 4      United States  295800000.0       3600000.0
# ..               ...          ...             ...
# 995           Russia    7700000.0        318200.0
# 996          Germany   11500000.0        210200.0
# 997            India   10100000.0        239800.0
# 998            India   13700000.0        175500.0
# 999           Mexico    6200000.0        391900.0
#
#                               Title
# 0                 Cristiano Ronaldo
# 1                           Kylie 🤍
# 2                         Leo Messi
# 3                           Kendall
# 4                      Selena Gomez
# ..                              ...
# 995                      Dina Saeva
# 996                    Manuel Neuer
# ...

# %% [markdown]
# # 2c.Find out how many influencers had Indian audiences, their profession, their number of followers and their average engagement

# %%
#The number of Indian audiences, their profession, their number of followers and their average engagement
dt=df[(df['Audience Country']=='India')]
pd.set_option('display.max_rows',143)
dt
# Out:
#     Audience Country    Followers  Engagement avg  \
# 0              India  400100000.0       9500000.0
# 14             India  182600000.0       2400000.0
# 19             India  219800000.0       1800000.0
# 27             India  295800000.0        994800.0
# 28             India  469600000.0        608100.0
# 29             India   44500000.0       6000000.0
# 35             India   61600000.0       3800000.0
# 43             India   56900000.0       2400000.0
# 44             India   65300000.0       2000000.0
# 50             India   33400000.0       3200000.0
# 54             India   59500000.0       1600000.0
# 57             India   53500000.0       1500000.0
# 59             India   21600000.0       3600000.0
# 61             India   28600000.0       2700000.0
# 64             India   74000000.0        997000.0
# 70             India   68900000.0        921500.0
# 77             India   71100000.0        866300.0
# 80             India   58900000.0        970900.0
# ...

# %%
#the number is shown below
dt.shape
# Out:
# (143, 4)

# %% [markdown]
# # 2d.What percentage of influencers with average engagement less than 1.5 million were into Beauty and Lifestyle?

# %%
b_l=data[['Category','Engagement avg']]
b_l.shape
# Out:
# (1000, 2)

# %%
#numbinfluencers with Engagement avg less than 1.5 million that are in Beauty and lifestyle  
b_l1=b_l[(b_l['Engagement avg']<150000) & (b_l['Category']=='Beauty')]
b_l1
# Out:
#     Category  Engagement avg
# 695   Beauty         77000.0

# %%
#the percentage is printed out as shown bellow
percentage=1/1000*100
percentage
# Out:
# 0.1

# %% [markdown]
# # 2e.What percentage of the influencers were into Sports with a ball, find out the difference between their average engagements and authentic engagements?

# %%
#The number of influencers who are into Sports with a ball
wh=data[(data['Category']=='Sports with a ball')]
wh
# Out:
#     Country  Rank               Account                      Title  \
# 0       All     1             cristiano          Cristiano Ronaldo
# 10      All    11              neymarjr                      NJ 🇧🇷
# 14      All    15           virat.kohli                Virat Kohli
# 38      All    39             kingjames                          👑
# 40      All    41              k.mbappe             Kylian Mbappé
# 53      All    54           fcbarcelona               FC Barcelona
# 60      All    61               mosalah              Mohamed Salah
# 79      All    80             paulpogba          Paul Labile Pogba
# 83      All    84            realmadrid           Real Madrid C.F.
# 101     All   102           paulodybala               Paulo Dybala
# 107     All   108  iamzlatanibrahimovic         Zlatan Ibrahimović
# 108     All   109          karimbenzema              Karim Benzema
# 116     All   117           sergioramos               Sergio Ramos
# ...

# %%
#the number is printed out below
wh.shape
# Out:
# (103, 11)

# %%
#Percentage of influencers who are into sports with a ball 
percentage1=103/1000*100
percentage1
# Out:
# 10.299999999999999

# %%
wh1=wh[(wh['Category']=='Sports with a ball') & (wh['Engagement avg'])]
wh1.shape
# Out:
# (103, 11)

# %%
wh2=wh[(wh['Category']=='Sports with a ball') & (wh['Authentic engagement'])]
wh2.shape
# Out:
# (103, 11)

# %%
#There is no difference with regards to their number
whole=103-103
whole
# Out:
# 0

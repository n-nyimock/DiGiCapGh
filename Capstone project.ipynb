# %%
import pandas as pd
from sklearn import*
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.simplefilter('ignore')
from scipy import stats
import seaborn as sns

# %%
dataset=pd.read_csv("capstoneddt.csv")
dataset.head(50)
# Out:
#          wxyhe                                   wdyptsic  \
# 0   Loneliness  In front Just close to the lecturer/tutor
# 1   Loneliness  In front Just close to the lecturer/tutor
# 2         Fear                                At the back
# 3      Sadness  In front Just close to the lecturer/tutor
# 4        Guilt                                   Anywhere
# 5      Sadness  In front Just close to the lecturer/tutor
# 6      Sadness  In front Just close to the lecturer/tutor
# 7      Sadness  In front Just close to the lecturer/tutor
# 8      Sadness                              In the middle
# 9      Sadness  In front Just close to the lecturer/tutor
# 10        Fear                              In the middle
# 11  Loneliness                              In the middle
# 12        Fear                              In the middle
# 13        Fear                              In the middle
# 14        Fear                              In the middle
# ...

# %%
le = preprocessing.LabelEncoder()
dataset['wxyhe']=le.fit_transform(dataset.wxyhe.values)
dataset['wdyptsic']=le.fit_transform(dataset.wdyptsic.values)
dataset['wdydwqxa']=le.fit_transform(dataset.wdydwqxa.values)
dataset['wdydwqxa_udka']=le.fit_transform(dataset.wdydwqxa_udka.values)
dataset.head(20)
# Out:
#     wxyhe  wdyptsic  wdydwqxa  wdydwqxa_udka  \
# 0       2         2         1              2
# 1       2         2         1              0
# 2       0         1         1              1
# 3       3         2         0              2
# 4       1         0         0              2
# 5       3         2         0              3
# 6       3         2         0              2
# 7       3         2         1              3
# 8       3         3         2              0
# 9       3         2         1              3
# 10      0         3         0              1
# 11      2         3         1              3
# 12      0         3         1              3
# 13      0         3         1              3
# 14      0         3         1              3
# 15      0         3         1              3
# 16      0         3         1              3
# 17      0         3         1              3
# 18      0         3         1              3
# 19      0         3         1              3
#
# ...

# %%
categorical_features = ['wxyhe','wdyptsic','wdydwqxa','wdydwqxa_udka']

for col in categorical_features:
    counts = dataset[col].value_counts().sort_index()
    fig = plt.figure(figsize=(9, 6))
    ax = fig.gca()
    counts.plot.bar(ax = ax, color='steelblue')
    ax.set_title(col + ' counts')
    ax.set_xlabel(col) 
    ax.set_ylabel("Frequency")
plt.show()

# %%
sns.heatmap(dataset.corr(), cmap="YlGnBu", annot=True)
plt.show()

# %%
x = dataset["wxyhe"]
y=dataset["wdyptsic"]



plt.bar(x,y)
plt.show()
